# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishikakaur8072005/Flyrank/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ishikakaur8072005/Flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Structured Content Archetype Clustering*
#
# I chose Structured Content Archetype Clustering because it aims to discover meaningful groups of content pages based on observable search and content metrics. Understanding these archetypes can help content teams apply different strategies to different types of pages instead of treating every page the same.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision** :- Decide which groups of content pages should receive different content strategies.
#
# **Action** :- Apply an appropriate strategy to each cluster, such as updating, monitoring, expanding, merging, or maintaining the content.
#
# **Cost of a wrong recommendation** :- If pages are grouped incorrectly, the content team may spend time improving the wrong pages or miss opportunities to improve pages that actually need attention.
#
# **Why data / ML?** :- The dataset contains thousands of pages with many performance metrics. It is difficult to manually identify natural patterns across all pages. Clustering can help discover groups of similar pages and support consistent content decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains **30,000 content pages** across **32 anonymized clients** and includes **44 features** describing search and content performance.
#
# These numbers suggest that the dataset is large enough to explore patterns across different types of content. Since there are many pages with multiple performance metrics, clustering may help identify groups of pages with similar characteristics that can later be mapped to different content strategies.

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("/content/content_refresh_anonymized.csv")

# Show 3 real numbers
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Unique clients:", df["client_id"].nunique())
# Out:
# Rows: 30000
# Columns: 44
# Unique clients: 32

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ### What I can and can't claim
#
# This notebook defines a proposed machine learning problem and an initial direction for exploration. The goal is to investigate whether content pages can be grouped into meaningful performance archetypes using the available search and content metrics.
#
# At this stage, I cannot claim that the clusters will be meaningful, optimal, or directly improve SEO performance. Any patterns discovered will need to be validated, interpreted, and evaluated before they can be used to support real content decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅] No client names, URLs, or private queries anywhere
# - [✅] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
